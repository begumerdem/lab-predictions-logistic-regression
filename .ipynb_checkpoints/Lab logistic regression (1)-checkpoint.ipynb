# %% [markdown]
# # Lab | Making predictions with logistic regression
#
# In this lab, you will be using the [Sakila](https://dev.mysql.com/doc/sakila/en/) database of movie rentals.
#
# In order to optimize our inventory, we would like to know which films will be rented next month and we are asked to create a model to predict it.
#
#
# ### Instructions
#
# 1. Create a query or queries to extract the information you think may be relevant for building the prediction model. It should include some film features and some rental features. Use the data from 2005.
# 2. Create a query to get the list of films and a boolean indicating if it was rented last month (May 2005). This would be our target variable.
# 3. Read the data into a Pandas dataframe.
# 4. Analyze extracted features and transform them. You may need to encode some categorical variables, or scale numerical variables.
# 5. Create a logistic regression model to predict this variable from the cleaned data.
# 6. Evaluate the results.

# %% [markdown]
# ## Import libraries and get database password

# %%
import pymysql
from sqlalchemy import create_engine
import pandas as pd
import getpass  # To get the password without showing the input
password = getpass.getpass()
# Out:
# ········

# %% [markdown]
# ## Get database data through sql

# %%
# get the data
connection_string = 'mysql+pymysql://root:' + password + '@localhost/sakila'
engine = create_engine(connection_string)
query = ''' select title, rental_duration, rental_rate, length, replacement_cost, rating, category, rented_may
            from(
            select film_id,
            case
            when month(rental_date) = 5 then True
            else False
            end as rented_may
            from rental
            join inventory using(inventory_id)
            join film using(film_id)
            join film_category using(film_id)
            join category using (category_id)
            where year(rental_date) = 2005 and month(rental_date) = 5
            group by film_id) t1
            right join(
            select rental_date, title, film_id, rental_duration, rental_rate, length, replacement_cost, rating, category.name as category
            from rental
            join inventory using(inventory_id)
            join film using(film_id)
            join film_category using(film_id)
            join category using (category_id)
            where year(rental_date) = 2005
            group by film_id
            ) t2
            using (film_id)
            order by title asc'''

data = pd.read_sql_query(query, engine)
data.head(30)
# Out:
#                    title  rental_duration  rental_rate  length  \
# 0       ACADEMY DINOSAUR                6         0.99      86
# 1         ACE GOLDFINGER                3         4.99      48
# 2       ADAPTATION HOLES                7         2.99      50
# 3       AFFAIR PREJUDICE                5         2.99     117
# 4            AFRICAN EGG                6         2.99     130
# 5           AGENT TRUMAN                3         2.99     169
# 6        AIRPLANE SIERRA                6         4.99      62
# 7        AIRPORT POLLOCK                6         4.99      54
# 8          ALABAMA DEVIL                3         2.99     114
# 9       ALADDIN CALENDAR                6         4.99      63
# 10       ALAMO VIDEOTAPE                6         0.99     126
# 11        ALASKA PHANTOM                6         0.99     136
# 12           ALI FOREVER                4         4.99     150
# 13          ALIEN CENTER                5         2.99      46
# 14       ALLEY EVOLUTION                6         2.99     180
# 15            ALONE TRIP                3         0.99      82
# 16         ALTER VICTORY                6         0.99      57
# 17          AMADEUS HOLY                6         0.99     113
# 18   AMELIE HELLFIGHTERS                4         4.99      79
# 19       AMERICAN CIRCUS                3         4.99     129
# 20     AMISTAD MIDSUMMER                6         2.99      85
# 21  ANACONDA CONFESSIONS                3         0.99      92
# 22      ANALYZE HOOSIERS                6         2.99     181
# 23           ANGELS LIFE                3         2.99      74
# 24        ANNIE IDENTITY                3         0.99      86
# 25       ANONYMOUS HUMAN                7         0.99     179
# 26           ANTHEM LUKE                5         4.99      91
# 27    ANTITRUST TOMATOES                5         2.99     168
# 28     ANYTHING SAVANNAH                4         2.99      82
# 29         APACHE DIVINE                5         4.99      92
#
#     replacement_cost rating     category  rented_may
# 0              20.99     PG  Documentary         1.0
# 1              12.99      G       Horror         NaN
# 2              18.99  NC-17  Documentary         1.0
# 3              26.99      G       Horror         1.0
# 4              22.99      G       Family         1.0
# 5              17.99     PG      Foreign         1.0
# 6              28.99  PG-13       Comedy         NaN
# 7              15.99      R       Horror         1.0
# 8              21.99  PG-13       Horror         NaN
# 9              24.99  NC-17       Sports         NaN
# 10             16.99      G      Foreign         1.0
# 11             22.99     PG        Music         1.0
# 12             21.99     PG       Horror         NaN
# 13             10.99  NC-17      Foreign         1.0
# 14             23.99  NC-17      Foreign         1.0
# 15             14.99      R        Music         1.0
# 16             27.99  PG-13    Animation         1.0
# 17             20.99     PG       Action         1.0
# 18             23.99      R        Music         NaN
# 19             17.99      R       Action         1.0
# 20             10.99      G          New         NaN
# 21              9.99      R    Animation         1.0
# 22             19.99      R       Horror         NaN
# 23             15.99      G          New         1.0
# 24             15.99      G       Sci-Fi         1.0
# 25             12.99  NC-17       Sports         NaN
# 26             16.99  PG-13       Comedy         1.0
# 27             11.99  NC-17       Action         1.0
# 28             27.99      R       Horror         1.0
# 29             16.99  NC-17       Family         1.0

# %%
# Has to be categorized --- probably gonna drop this one
data['replacement_cost'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [1], in <cell line: 2>()
#       1 # Has to be categorized --- probably gonna drop this one
# ----> 2 data['replacement_cost'].value_counts()
#
# NameError: name 'data' is not defined

# %%
# Has to be categorized
data['rental_duration'].value_counts()
# Out:
# 6    203
# 3    197
# 4    194
# 5    186
# 7    178
# Name: rental_duration, dtype: int64

# %%
# Has to be categorized categorized
data['rental_rate'].value_counts()
# Out:
# 0.99    326
# 4.99    320
# 2.99    312
# Name: rental_rate, dtype: int64

# %%
# bining the movies. 0,90,120,180-max
data['length'].value_counts()
# Out:
# 85     17
# 179    13
# 84     13
# 112    12
# 122    11
#        ..
# 94      3
# 96      2
# 55      2
# 66      2
# 95      2
# Name: length, Length: 140, dtype: int64

# %%
data.isna().sum()
# Out:
# title                 0
# rental_duration       0
# rental_rate           0
# length                0
# replacement_cost      0
# rating                0
# category              0
# rented_may          272
# dtype: int64
